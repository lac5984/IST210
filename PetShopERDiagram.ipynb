# %% [markdown]
# <a href="https://colab.research.google.com/github/lac5984/IST210/blob/master/PetShopERDiagram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![fullsizeoutput_e96.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# My reasoning for the way that I displayed and put together my ER diagram is looking at all of the relationships and attributes that correlated with the entities. With these relationships I drew arrows pointing and describing these relationships. I found that some of the entities had more than one relationship. With these relationships I had to figure out how they related. The only foreign key that I found was the customer loyalty program. The reason I found this to be a froeign key is because it does not apply to all customers and can change many attributes when making an adoption or food transaction.
